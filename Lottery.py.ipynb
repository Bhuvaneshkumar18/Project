# %%
def winwin(func):
    def inner():
        print("welcome to the kerala lootrey".upper())
        func
    inner()
    
    def inner1():
        print('address:90,goiyanda street,kerala'.upper())
        print('phoneno:3284724874')
        print('Lottery')
    inner1()
winwin('func')

# %%
class common(object):
    @winwin()
    def __init__(self,data):
        self.data=data
##FIRST PRIZE:
    def first(self):
        import random
        self.data=data
        print("THE FIRST PRIZE:")
        key=list(data.keys())
        value=list(data.values())
        choice1=random.choice(key)
        choice2=random.choice(value)
        random1=random.randint(10001,11000)
        print(choice1,random1,choice2)

#3SECOND PRIZE:
    def second(self):
        import  random
        self.data=data
        print('The second prize is:')
        key=list(data.keys())
        value=list(data.values())
        choice1=random.choice(key)
        choice2=random.choice(value)
        random1=random.randint(10001,11000)
        print(choice1,random1,choice2)
        
##CONSOLATION PRIZE
    def consolation(self):
        import random
        print('THE CONSOLATION PRIZES:')
        key=list(data.keys())
        value=list(data.values())
        choice1=random.choice(key)
        choice2=random.choice(value)
        random1=random.randint(10001,11000)
        print(choice1,random1,choice2)
        
##THIRD PRIZE:
    def third(self):
        import random
        print('THE 3rd PRIZE IS Rs:100000-/-:')
        key=list(data.keys())
        value=list(data.values())
        choice1=random.choice(key)
        choice2=random.choice(value)
        random1=random.randint(10001,11000)
        for i in range(0,1):
            print(choice1,random1,choice2)
#FOURTH PRIZE:
#CALL THE CLASS IN COMMON:
class winwin_prize(common):
    def fourth(self):
        import random
        print('THE FOURTH PRIZE IS:')
        for i in range(0,5):
            random1=random.randint(10001,11000)
            print('\t',random1)
            
#FIFTHPRIZE:
    def fifth(self):
        import random
        print('THE FIFTH PRIZE:')
        for i in range(0,7):
            random1=random.randint(10001,11000)
            print('\t',random1,end=" ")    
data={'WA':'(IRANJIKILADU)','WP':'(mUDIMALAI)','WQ':'(KIANYA)','WO':'(WALLARIPET)','WS':'(THANDAR)','WD':'(UNIOMNGH)','WR':'(RATION)'}
c=winwin_prize(data)
c.first()
c.second()
c.third()
c.consolation()
c.fourth()
c.fifth()
